# %% [markdown]
# # 24 — Capstone Projects (Beginner → Advanced)
#
# Goal: consolidate everything by building real, shippable tools.

# %% [markdown]
# _Generated: 2026-02-19_

# %% [markdown]
# ## Setup
#
# This course targets **Python 3.11+** (works on 3.10+, with a few feature differences).
#
# Recommended tooling:
#
# ```bash
# # create + activate a virtual environment
# python -m venv .venv
# # mac/linux:
# source .venv/bin/activate
# # windows (PowerShell):
# # .venv\Scripts\Activate.ps1
#
# python -m pip install -U pip
#
# # quality-of-life (optional but recommended)
# python -m pip install -U ipykernel ruff black pytest mypy
# python -m pip install -U requests httpx rich typer
# ```
#
# If you're using Jupyter:
# ```bash
# python -m ipykernel install --user --name python-course --display-name "Python Course (.venv)"
# ```

# %%
import sys, platform, os
print("python:", sys.version.split()[0])
print("implementation:", platform.python_implementation())
print("platform:", platform.platform())
print("cwd:", os.getcwd())

# %% [markdown]
# ## 1.
# L1: Project 1 (Beginner): “CSV Summarizer” CLI
#
# Build a CLI tool that:
# - reads a CSV file
# - computes summary statistics (count, min, max, mean for numeric columns)
# - prints a report
#
# Skills:
# - argparse
# - csv module
# - functions + tests
# - packaging as `project.scripts`

# %% [markdown]
# ### Suggested structure
#
# ```
# csvsum/
#   pyproject.toml
#   src/csvsum/__init__.py
#   src/csvsum/cli.py
#   tests/test_cli.py
# ```

# %% [markdown]
# ## 2.
# L2: Project 2 (Intermediate): “Directory Auditor”
#
# Build a tool that:
# - scans a directory
# - groups files by extension
# - reports total size by group
# - optionally outputs JSON
#
# Skills:
# - pathlib, os/stat
# - dataclasses
# - JSON serialization
# - logging

# %% [markdown]
# ## 3.
# L3: Project 3 (Intermediate): “SQLite-backed Notes App”
#
# Build a small library + CLI:
# - `add`, `list`, `search`, `delete`
# - stores notes in SQLite
# - includes migrations/versioning
#
# Skills:
# - sqlite3 transactions
# - parameterized queries
# - testing

# %% [markdown]
# ## 4.
# L4: Project 4 (Advanced): “Async URL Crawler”
#
# Build an async tool that:
# - fetches many URLs concurrently with timeouts
# - respects a concurrency limit
# - stores results (status, size, timing) in SQLite
# - retries transient failures
#
# Skills:
# - asyncio + aiohttp/httpx
# - cancellation/timeouts
# - concurrency limits (Semaphore)
# - persistence

# %% [markdown]
# ## 5.
# L5: Project 5 (Advanced): “Publish a Package”
#
# Take any of the above and:
# - package it properly with `pyproject.toml`
# - add a CLI entry point
# - add CI (ruff/black/mypy/pytest)
# - build wheels/sdists
# - optionally publish to TestPyPI
#
# Skills:
# - packaging
# - tooling
# - release discipline

# %% [markdown]
# ## 6.
# L6: Minimal templates you can copy
#
# ### A minimal `main()` for a CLI (argparse)

# %%
import argparse

def main(argv: list[str] | None = None) -> int:
    p = argparse.ArgumentParser()
    p.add_argument("name")
    args = p.parse_args(argv)
    print(f"Hello, {args.name}!")
    return 0

# demo call inside notebook
main(["World"])

# %% [markdown]
# ### A minimal project checklist
#
# - [ ] clear README with install + usage
# - [ ] reproducible env (pinned dependencies)
# - [ ] tests run in CI
# - [ ] logging (no prints) for long-running programs
# - [ ] type hints on public APIs
# - [ ] error handling with actionable messages
