# %% [markdown]
# # 92 — Appendix: Resources and Next Steps
#
# Goal: where to look when you hit the edge of your knowledge.

# %% [markdown]
# _Generated: 2026-02-19_

# %% [markdown]
# ## Official docs
#
# - Python language reference (core semantics)
# - Python standard library reference
# - `typing` docs
# - Packaging user guide (`pyproject.toml`, builds, publishing)
#
# ## High-value reading
#
# - PEP 8 (style)
# - PEP 20 (Zen of Python): `import this`
# - “Data model” docs (dunder methods)
# - “Logging HOWTO”
#
# ## Practice ideas
#
# - Solve small problems daily (string parsing, file manipulation, algorithms).
# - Build tools that automate your own workflow.
# - Read code from high-quality libraries to learn idioms.

# %%
import this
